# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'C:\\Users\\ADMIN\\Documents\\TseClient 2.0\\Adjusted\\IRO3SHHZ0001-a.csv'
s = open(path)
str = s.read()
str
# Out:
# 'ÿþ<\x00D\x00T\x00Y\x00Y\x00Y\x00Y\x00M\x00M\x00D\x00D\x00>\x00,\x00<\x00O\x00P\x00E\x00N\x00>\x00,\x00<\x00H\x00I\x00G\x00H\x00>\x00,\x00<\x00L\x00O\x00W\x00>\x00,\x00<\x00C\x00L\x00O\x00S\x00E\x00>\x00,\x00<\x00V\x00O\x00L\x00>\x00,\x00<\x00O\x00P\x00E\x00N\x00I\x00N\x00T\x00>\x00\n\x00\n\x002\x000\x001\x007\x000\x001\x000\x004\x00,\x001\x008\x002\x00.\x008\x007\x00,\x001\x008\x003\x00,\x001\x008\x003\x00,\x001\x008\x002\x00.\x008\x007\x00,\x001\x003\x002\x001\x000\x004\x006\x008\x00,\x001\x004\x001\x00\n\x00\n\x002\x000\x001\x007\x000\x001\x000\x007\x00,\x001\x009\x002\x00.\x000\x001\x00,\x001\x009\x002\x00,\x001\x009\x002\x00,\x001\x009\x002\x00.\x000\x001\x00,\x001\x008\x001\x005\x002\x004\x007\x008\x00,\x001\x008\x003\x00\n\x00\n\x002\x000\x001\x007\x000\x001\x000\x008\x00,\x001\x009\x006\x00.\x007\x009\x00,\x002\x000\x002\x00,\x001\x009\x004\x00,\x002\x000\x000\x00.\x004\x005\x00,\x002\x005\x000\x001\x005\x007\x009\x009\x00,\x001\x009\x002\x00\n\x00\n\x002\x000\x001\x007\x000\
# ...
