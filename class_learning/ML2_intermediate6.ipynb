# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from nilearn import  image
from nilearn import plotting
from nilearn.decomposition import canica

# %%
adr='F:\my project\dataset\learning_dataset\sub-PAT26_T1w.nii\\sub-PAT26_T1w.nii'

# %%
#fist_image=image.index_img(adr,0)
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fist_image=image.index_img(adr,0)
#
# File c:\users\admin\pycharmprojects\pythonproject5\venv\lib\site-packages\nilearn\image\image.py:654, in index_img(imgs, index)
#     601 def index_img(imgs, index):
#     602     """Indexes into a 4D Niimg-like object in the fourth dimension.
#     603
#     604     Common use cases include extracting a 3D image out of `img` or
#    (...)
#     652
#     653     """
# --> 654     imgs = check_niimg_4d(imgs)
#     655     # duck-type for pandas arrays, and select the 'values' attr
#     656     if hasattr(index, 'values') and hasattr(index, 'iloc'):
#
# File c:\users\admin\pycharmprojects\pythonproject5\venv\lib\site-packages\nilearn\_utils\niimg_conversions.py:382, in check_niimg_4d(niimg, return_iterator, dtype)
# ...

# %%
#img=image.smooth_img(adr,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 img=image.smooth_img(adr)
#
# TypeError: smooth_img() missing 1 required positional argument: 'fwhm'

# %%
from nilearn import datasets

# %%
haxby_dataset = datasets.fetch_haxby()
# Out:
# Dataset created in C:\Users\ADMIN/nilearn_data\haxby2001
#
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
# Downloaded 284688384 of 291168628 bytes (97.8%,    1.1s remaining) ...done. (50 seconds, 0 min)
# Extracting data from C:\Users\ADMIN/nilearn_data\haxby2001\0a7df7e6986f9ca94043f4c67ae3792a\subj2-2010.01.14.tar.gz..... done.

# %%
haxby_dataset['anat']
# Out:
# ['C:\\Users\\ADMIN/nilearn_data\\haxby2001\\subj2\\anat.nii.gz']

# %%
img=image.index_img(haxby_dataset['anat'],0)
img

# %%
plotting.plot_prob_atlas(img)
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plotting.plot_prob_atlas(img)
#
# File c:\users\admin\pycharmprojects\pythonproject5\venv\lib\site-packages\nilearn\plotting\img_plotting.py:770, in plot_prob_atlas(maps_img, bg_img, view_type, threshold, linewidths, cut_coords, output_file, display_mode, figure, axes, title, annotate, draw_cross, black_bg, dim, colorbar, cmap, vmin, vmax, alpha, **kwargs)
#     691 """Plot the probabilistic atlases onto the anatomical image
#     692 by default MNI template
#     693
#    (...)
#     762
#     763 """
#     764 display = plot_anat(bg_img, cut_coords=cut_coords,
#     765                     display_mode=display_mode,
#     766                     figure=figure, axes=axes, title=title,
#     767                     annotate=annotate, draw_cross=draw_cross,
# ...
