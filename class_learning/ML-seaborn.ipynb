# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
import seaborn as sb

# %%
path = 'C:\\Users\\ADMIN\\AppData\\Roaming\\MetaQuotes\\Terminal\\D0E8209F77C8CF37AD8BF550E51FF075\\MQL5\\Files\\OIL-W1.prn'
oil_data = pd.read_csv(path)
oil_data
oil = oil_data[:][100:110]
oil
# Out:
#      <DTYYYYMMDD>  <TIME>  <OPEN>  <HIGH>  <LOW>  <CLOSE>    <VOL>
# 100      20111016       0   87.48   89.51  84.10    87.53   577782
# 101      20111023       0   87.05   94.65  87.00    93.49  1330735
# 102      20111030       0   93.53   94.93  89.17    94.42  1066955
# 103      20111106       0   94.40   99.40  93.23    99.22  1092810
# 104      20111113       0   99.30  103.37  96.70    97.79  1170258
# 105      20111120       0   97.54   98.70  94.99    97.32   808485
# 106      20111127       0   97.50  101.75  97.13   101.13  1099497
# 107      20111204       0  101.23  102.44  97.36    99.83  1016457
# 108      20111211       0   99.58  101.25  92.52    93.78  1062538
# 109      20111218       0   93.77  100.23  92.77    99.86   677192

# %%
sb.stripplot(x='<DTYYYYMMDD>', y='<CLOSE>', data=oil)
plt.show()

# %%
sb.swarmplot(x='<DTYYYYMMDD>', y='<CLOSE>', data=oil, hue='<VOL>')
# Out:
# <AxesSubplot:xlabel='<DTYYYYMMDD>', ylabel='<CLOSE>'>

# %%
sb.boxplot(y='<CLOSE>', data=oil)
plt.show()

# %%
sb.boxplot(x='<VOL>', y='<CLOSE>', data=oil)
plt.show()

# %%
sb.jointplot(x='<DTYYYYMMDD>', y='<CLOSE>', data=oil, kind='scatter')
plt.show()

# %%
sb.pairplot(data=oil)
plt.show()

# %%
a = oil['<CLOSE>'].values
b = oil['<VOL>'].values

# %%
cor=np.corrcoef(a,b)
cor
# Out:
# array([[1.       , 0.2568248],
#        [0.2568248, 1.       ]])
