# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import openpyxl

# %%
path = "C:\\Users\\ADMIN\\Desktop\\my project\\currecies.xlsx"
curr_data = pd.read_excel(path)
curr_data
# Out:
#         year/currency      1960      1961      1962      1963      1964  \
# 0       chf inflation  1.438795  1.845398  4.315993  3.440213  3.080557
# 1   inflation adj chf  0.985612  0.967424  0.925670  0.893825  0.866290
# 2       usd inflation  1.457976  1.070724  1.198773  1.239669  1.278912
# 3   inflation adj usd  0.985420  0.974869  0.963183  0.951242  0.939077
# 4       aud inflation  3.728814  2.287582 -0.319489  0.641026  2.866242
# 5   inflation adj aud  0.962712  0.940689  0.943694  0.937645  0.910770
# 6        ir inflation  9.822411  3.162564  0.721321  0.371850  3.814490
# 7    inflation adj ir  0.901776  0.873257  0.866958  0.863734  0.830787
# 8                 NaN       NaN       NaN       NaN       NaN       NaN
# 9              usd/ir  1.092755  1.116360  1.110992  1.101314  1.130346
# 10            usd/chf  0.999805  1.007696  1.040525  1.064238  1.084021
# 11            aud/usd  0.976956  0.964939  0.979767  0.985706  0.969857
#
# ...

# %%
usdchf = curr_data.loc[10][1:]

# %%
usdchf
# Out:
# 1960    0.999805
# 1961    1.007696
# 1962    1.040525
# 1963    1.064238
# 1964    1.084021
#           ...
# 2018    0.457877
# 2019    0.451217
# 2020    0.442439
# 2021    0.424121
# 2022    0.401291
# Name: 10, Length: 63, dtype: object

# %%
plt.plot(usdchf)

# %%
year = [1350, 1360, 1370, 1380, 1390, 1400]
iran_pop = [30, 50, 70, 75, 80, 83]
plt.plot(year, iran_pop)

# %%
plt.scatter(year, iran_pop)

# %%
city = ['mashhad', 'tehran', 'karaj', 'isfahan']
city_pop = [2, 10, 4, 3]
plt.hist(city_pop, bins='auto')
# Out:
# (array([3., 0., 1.]),
#  array([ 2.        ,  4.66666667,  7.33333333, 10.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.pie(city_pop, labels=city)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c71cfb6950>,
# ...
#  [Text(1.0403989649906822, 0.3571694186885514, 'mashhad'),
#   Text(-0.7450097806321688, 0.8092962540148124, 'tehran'),
#   Text(-0.09083713956801406, -1.0962429539454752, 'karaj'),
#   Text(0.9674211856641685, -0.5235420226955375, 'isfahan')])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(3, 3), dpi=200)
plt.plot(usdchf)
plt.xlabel('year')
plt.ylabel('USDCHF')
#plt.yticks([0.4, 0.6, 0.8, 10], ['0.4i', '0.6i', '0.8i', '1i'])
# Out:
# Text(0, 0.5, 'USDCHF')

# %%
pop_size = iran_pop
color = ['blue', 'red', 'green', 'black', 'pink', 'violet']
plt.scatter(year, iran_pop, s=pop_size, c=color)
plt.title('Iran Population')
plt.margins(0.2)
plt.text(1405, 83, 'End', fontsize=15)
plt.xlabel('year')
plt.ylabel('population')
plt.figure(figsize=(3, 3), dpi=300)

# %%
curr_data
# Out:
#         year/currency      1960      1961      1962      1963      1964  \
# 0       chf inflation  1.438795  1.845398  4.315993  3.440213  3.080557
# 1   inflation adj chf  0.985612  0.967424  0.925670  0.893825  0.866290
# 2       usd inflation  1.457976  1.070724  1.198773  1.239669  1.278912
# 3   inflation adj usd  0.985420  0.974869  0.963183  0.951242  0.939077
# 4       aud inflation  3.728814  2.287582 -0.319489  0.641026  2.866242
# 5   inflation adj aud  0.962712  0.940689  0.943694  0.937645  0.910770
# 6        ir inflation  9.822411  3.162564  0.721321  0.371850  3.814490
# 7    inflation adj ir  0.901776  0.873257  0.866958  0.863734  0.830787
# 8                 NaN       NaN       NaN       NaN       NaN       NaN
# 9              usd/ir  1.092755  1.116360  1.110992  1.101314  1.130346
# 10            usd/chf  0.999805  1.007696  1.040525  1.064238  1.084021
# 11            aud/usd  0.976956  0.964939  0.979767  0.985706  0.969857
#
# ...

# %%
audusd = curr_data.loc[11][1:]
audusd
# Out:
# 1960    0.976956
# 1961    0.964939
# 1962    0.979767
# 1963    0.985706
# 1964    0.969857
#           ...
# 2018    0.511357
# 2019    0.512406
# 2020    0.514413
# 2021    0.524312
# 2022    0.544389
# Name: 11, Length: 63, dtype: object

# %%
plt.plot(usdchf, ls='-', mew=4)
plt.plot(audusd)
plt.legend(['USDCHF', 'AUDUSD'], loc='best')
plt.grid()
plt.annotate('Currency War', xy=(1983, 0.76), xytext=(2003, 0.8), arrowprops={'facecolor': 'blue'},
             fontsize=15)
plt.show()

# %%
chus = curr_data[:][10:11]
chus.columns[0]
ch=chus[chus.columns[1:]]
ch
# Out:
#         1960      1961      1962      1963      1964      1965      1966  \
# 10  0.999805  1.007696  1.040525  1.064238  1.084021  1.104553  1.124978
#
#         1967      1968      1969  ...      2013      2014      2015     2016  \
# 10  1.139421  1.117521  1.083445  ...  0.494814  0.486723  0.480647  0.47253
#
#         2017      2018      2019      2020      2021      2022
# 10  0.464946  0.457877  0.451217  0.442439  0.424121  0.401291
#
# [1 rows x 63 columns]

# %%
usdchf
audusd
# Out:
# 1960    0.976956
# 1961    0.964939
# 1962    0.979767
# 1963    0.985706
# 1964    0.969857
#           ...
# 2018    0.511357
# 2019    0.512406
# 2020    0.514413
# 2021    0.524312
# 2022    0.544389
# Name: 11, Length: 63, dtype: object

# %%
plt.subplot(1,2,1)
plt.plot(usdchf)
plt.title('USDCHF')
plt.subplot(1,2,2)
plt.plot(audusd)
plt.title('AUDUSD')
plt.show()
