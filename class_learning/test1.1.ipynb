# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import finpy_tse as tse
#import MetaTrader5 as mt

# %%
#mt.initialize('C:\\Program Files\\MofidTrader\\terminal64.exe')
# Out:
# True

# %%
market=tse.Build_Market_StockList(bourse=True,farabourse=True,payeh=False)
market
# Out:
# Progress : 100 % , Done in 19 seconds!
# Save path does not exist, you can handle saving this data by returned dataframe as Excel using ".to_excel()", if you will!
# Save path does not exist, you can handle saving this data by returned dataframe as CSV using ".to_csv()", if you will!
#                                  Name   Market                         Panel  \
# Ticker
# آباد    توریستی ورفاهی آبادگران ایران     بورس                بازار دوم بورس
# آبادا          تولید نیروی برق آبادان     بورس                بازار دوم بورس
# آپ                  آسان پرداخت پرشین     بورس  بازار اول (تابلوی فرعی) بورس
# آسیا                        بیمه آسیا     بورس  بازار اول (تابلوی اصلی) بورس
# اپال      فرآوری معدنی اپال کانی پارس     بورس                بازار دوم بورس
# ...                               ...      ...                           ...
# ولشرق              لیزینگ ایران و شرق  فرابورس             بازار اول فرابورس
# ...

# %%
matket_name=market.index
matket_name
# Out:
# Index(['آباد', 'آبادا', 'آپ', 'آسیا', 'اپال', 'اتکام', 'اخابر', 'اردستان',
#        'اسیاتک', 'افق',
#        ...
#        'وسپهر', 'وطوبی', 'وکبهمن', 'وگستر', 'ولبهمن', 'ولشرق', 'ومعلم', 'وملل',
#        'وهامون', 'وهور'],
#       dtype='object', name='Ticker', length=554)

# %%
sh=tse.Get_CWI_History(ignore_date=True)
sh
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# J-Date
# 1387-09-16     9249.0     9249.0     9168.0     9178.0     9178.3     8539624
# 1387-09-17     9178.0     9178.0     9130.0     9130.0     9130.5    11752353
# 1387-09-18     9103.0     9103.0     9080.0     9089.0     9089.2    15299115
# 1387-09-20     9072.0     9072.0     9024.0     9024.0     9023.7    15689653
# 1387-09-23     8973.0     8973.0     8973.0     8973.0     8973.3    31428174
# ...               ...        ...        ...        ...        ...         ...
# 1402-03-27  2185130.0  2189700.0  2182800.0  2182804.0  2182812.2  6727302847
# 1402-03-28  2181820.0  2181820.0  2162710.0  2162917.0  2162916.9  7459075366
# 1402-03-29  2162310.0  2168390.0  2162310.0  2164226.0  2164226.3  7705141387
# 1402-03-30  2164170.0  2166940.0  2161110.0  2166947.0  2166947.4  4905142581
# 1402-03-31  2168560.0  2177070.0  2168560.0  2173893.0  2173893.4  5194159667
#
# [3500 rows x 6 columns]

# %%
market_close=sh['Close']
market_close=pd.DataFrame(market_close)
market_close.rename(columns={'Close':'Shakhes_kol'},inplace=True)
market_close
# Out:
#             Shakhes_kol
# J-Date
# 1387-09-16       9178.0
# 1387-09-17       9130.0
# 1387-09-18       9089.0
# 1387-09-20       9024.0
# 1387-09-23       8973.0
# ...                 ...
# 1402-03-27    2182804.0
# 1402-03-28    2162917.0
# 1402-03-29    2164226.0
# 1402-03-30    2166947.0
# 1402-03-31    2173893.0
#
# [3500 rows x 1 columns]

# %%
tse.Get_Price_History(stock='فولاد',ignore_date=True,adjust_price=True)
# Out:
#             Open  High   Low  Close  Final     Volume         Value    No  \
# J-Date
# 1385-12-20  1900  1938  1900   1900   1900  468077431  889437216900  7736
# 1385-12-21  1938  1938  1938   1938   1938  100041000  193879458000  9214
# 1385-12-22  1976  1976  1915   1973   1973  126270939  249241504527  5862
# 1385-12-23  1934  1966  1934   1934   1934   26705128   51666379451  1901
# 1385-12-26  1896  1927  1896   1898   1898   14877283   28239006789  1514
# ...          ...   ...   ...    ...    ...        ...           ...   ...
# 1402-03-27  5820  5910  5750   5750   5810   63127519  366496391920  5687
# 1402-03-28  5790  5820  5590   5780   5770  121290120  700113177290  5627
# 1402-03-29  5820  5820  5680   5690   5710   99238817  566527478590  5748
# 1402-03-30  5710  5770  5640   5700   5680   46171020  262440230040  4077
# 1402-03-31  5700  5750  5570   5640   5660   74345505  420564575410  6119
#
# ...

# %%
for i in matket_name:
    market_close[i]=tse.Get_Price_History(stock=i,ignore_date=True,adjust_price=True)['Close']
market_close
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_860\1468697072.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   market_close[i]=tse.Get_Price_History(stock=i,ignore_date=True,adjust_price=True)['Close']
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_860\1468697072.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   market_close[i]=tse.Get_Price_History(stock=i,ignore_date=True,adjust_price=True)['Close']
# ...

# %%
market_close.to_excel('F:\my project\dataset\my pro-datasets\\tse\\all_market_close.xlsx')

# %%
corr=market_close.corr()
corr
# Out:
#              Shakhes_kol      آباد     آبادا        آپ      آسیا      اپال  \
# Shakhes_kol     1.000000  0.913426  0.291431 -0.195089  0.376721 -0.187348
# آباد            0.913426  1.000000  0.152509 -0.166291  0.223888  0.071318
# آبادا           0.291431  0.152509  1.000000  0.741144  0.820019  0.013049
# آپ             -0.195089 -0.166291  0.741144  1.000000  0.652259  0.043866
# آسیا            0.376721  0.223888  0.820019  0.652259  1.000000 -0.149376
# ...                  ...       ...       ...       ...       ...       ...
# ولشرق           0.563685  0.612656  0.761965  0.588390  0.632362 -0.240394
# ومعلم           0.093295 -0.021877  0.860511  0.899112  0.891015  0.007413
# وملل            0.657805  0.657905  0.625497  0.400063  0.593893  0.352314
# وهامون          0.500993  0.732949  0.814401  0.842936  0.737698  0.353773
# وهور            0.334042  0.206831  0.799443  0.609173  0.954853 -0.135860
#
# ...

# %%
corr.to_excel('F:\my project\dataset\my pro-datasets\\tse\\all_market_correlation.xlsx')

# %%
corr.describe()
# Out:
#        Shakhes_kol        آباد       آبادا          آپ        آسیا  \
# count   555.000000  555.000000  555.000000  555.000000  555.000000
# mean      0.490534    0.474702    0.546158    0.385737    0.546789
# std       0.382194    0.322977    0.335964    0.335923    0.296233
# min      -0.862481   -0.838297   -0.911053   -0.794123   -0.850047
# 25%       0.304320    0.265908    0.393391    0.164264    0.398487
# 50%       0.578836    0.543911    0.669467    0.435077    0.615569
# 75%       0.790062    0.729760    0.780248    0.642657    0.757685
# max       1.000000    1.000000    1.000000    1.000000    1.000000
#
#              اپال       اتکام       اخابر     اردستان      اسیاتک  ...  \
# count  554.000000  555.000000  555.000000  529.000000  529.000000  ...
# mean    -0.042488    0.674538    0.658196    0.619280   -0.360980  ...
# std      0.375851    0.283570    0.293421    0.413433    0.340083  ...
# min     -0.966440   -0.926130   -0.809597   -0.923948   -0.775040  ...
# ...

# %%
ret_market=market_close.pct_change()
ret_market
# Out:
#             Shakhes_kol     آباد     آبادا        آپ      آسیا      اپال  \
# J-Date
# 1387-09-16          NaN      NaN       NaN       NaN       NaN       NaN
# 1387-09-17    -0.005230      NaN       NaN       NaN       NaN       NaN
# 1387-09-18    -0.004491      NaN       NaN       NaN       NaN       NaN
# 1387-09-20    -0.007152      NaN       NaN       NaN       NaN       NaN
# 1387-09-23    -0.005652      NaN       NaN       NaN       NaN       NaN
# ...                 ...      ...       ...       ...       ...       ...
# 1402-03-27     0.000319  0.00000 -0.028044 -0.011066 -0.036150  0.014570
# 1402-03-28    -0.009111  0.00000 -0.017464 -0.016277  0.097046  0.008486
# 1402-03-29     0.000605  0.00000 -0.006955 -0.010341  0.005556 -0.018770
# 1402-03-30     0.001257  0.00000  0.019455 -0.005225 -0.025924  0.011873
# 1402-03-31     0.003205  0.05544 -0.015267  0.018908 -0.006981 -0.010430
#
#                اتکام     اخابر   اردستان    اسیاتک  ...     وسپهر     وطوبی  \
# ...

# %%
ret_market.to_excel('F:\my project\dataset\my pro-datasets\\tse\\all_market_return.xlsx')

# %%
mean_return_market=pd.Series(np.array([np.mean(ret_market[i]) for i in ret_market.columns]),index=ret_market.columns)
mean_return_market
# Out:
# Shakhes_kol    0.001621
# آباد           0.001595
# آبادا          0.000187
# آپ             0.000620
# آسیا           0.001381
#                  ...
# ولشرق          0.001842
# ومعلم          0.000882
# وملل           0.000903
# وهامون         0.001803
# وهور           0.001495
# Length: 555, dtype: float64

# %%
std_return_market=pd.Series(np.array([np.std(ret_market[i]) for i in ret_market.columns]),index=ret_market.columns)
std_return_market
# Out:
# Shakhes_kol    0.010698
# آباد           0.028455
# آبادا          0.030162
# آپ             0.033341
# آسیا           0.043701
#                  ...
# ولشرق          0.035234
# ومعلم          0.037324
# وملل           0.034084
# وهامون         0.031826
# وهور           0.036573
# Length: 555, dtype: float64
