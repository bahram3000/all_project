# %%
import os
#import string

import requests
#from bs4 import BeautifulSoup
import time
from tqdm import tqdm
import pandas as pd
#import numpy as np
from random import randint

# %%
requests.get('https://www.google.com').status_code
# Out:
# 200

# %%
requests.get('https://www.google.com', timeout=5)
# Out:
# <Response [200]>

# %%
requests.get('https://www.google.com').text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IR"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="kvCdfVJAVCDOCgOALZKx_g">(function(){var _g={kEI:\'iR26ZfD7DP7X5OUPzaOeuAM\',kEXPI:\'0,1361118,4349,207,4804,1132070,1962,868575,327224,380729,44799,23792,12316,17583,4998,17075,38444,2872,2891,4140,4209,3405,606,60690,2614,13721,1014,1,16916,2652,4,59617,27053,6624,7593,1,42154,2,16737,21266,1758,6700,31121,4569,6258,24670,33064,2,2,1,24626,2006,8155,23351,22435,9779,12415,30044,20199,73178,3030,15816,1804,7734,6072,13286,9137,10853,1633,56361,5209124,1015,2,296,70,586,482
# ...

# %%
def internet_connection():
    try:
        response = requests.get("https://www.google.com", timeout=5)
        return True
    except requests.ConnectionError:
        return False

# %%
internet_connection()
# Out:
# True

# %%
requests.get('https://divar.ir/v/_/QZ3K0_YL').status_code
# Out:
# 200

# %%
page = requests.get('https://divar.ir/v/_/QZ3yq2WQ').text

# %%
page
# Out:
# '<!doctype html>\n<html lang="fa-IR" dir="rtl">\n<head>\n  \n  \n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n  <meta name="format-detection" content="telephone=no" />\n  <meta name="referrer" content="strict-origin-when-cross-origin" />\n  <link rel="preconnect" href="https://s100.divarcdn.com" />\n  <link rel="dns-prefetch" href="https://s100.divarcdn.com">\n    <link href=https://s100.divarcdn.com/statics/2024/01/IRANSansWeb.cdb118d6.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link href=https://s100.divarcdn.com/statics/2024/01/IRANSansWeb_Medium.9f338149.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2024/01/runtime.784284d8.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/stat
# ...

# %%
soup = BeautifulSoup(page, 'html5lib')

# %%
soup.find_all('div', class_="post-page__section--padded")
# Out:
# []

# %%
for i in soup.find_all('div', class_="post-page__section--padded"):
    print(i.text)

# %%
for i in soup.find_all('div', class_="kt-base-row kt-base-row--large kt-unexpandable-row"):
    print(i.text)

# %%
for i in soup.find_all('div', class_="kt-base-row__end kt-unexpandable-row__value-box"):
    print(i.text)

# %%
soup.find_all('div', class_="kt-base-row__start")
# Out:
# []

# %%
for i in soup.find_all('div', class_="kt-base-row__start"):
    print(i.text)

# %%
#parent_tag = soup.find('div', class_="kt-base-row__start")
#parent_tag

# %%
#child = parent_tag.findChild()
#child

# %%
#child.next_sibling

# %%
soup.find_all('p', class_="kt-description-row__text kt-description-row__text--primary")
# Out:
# []

# %%
soup.find_all('p', class_="kt-description-row__text kt-description-row__text--primary")[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 soup.find_all('p', class_="kt-description-row__text kt-description-row__text--primary")[0].text
#
# IndexError: list index out of range

# %%
soup.find('div', class_='kt-page-title__title kt-page-title__title--responsive-sized').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 soup.find('div', class_='kt-page-title__title kt-page-title__title--responsive-sized').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
def adad_farsi_to_english(inp: str):
    dc = {'۰': '0', '۱': '1', '۲': '2', '۳': '3', '۴': '4', '۵': '5', '۶': '6', '۷': '7', '۸': '8', '۹': '9'}
    out = ''
    for i in inp:
        if i in dc.keys():
            out += dc[i]
        else:
            out += ''
    if out.isdecimal():
        return int(out)
    else:
        return None

# %%
def get_tokens(inp_url, inp_json):
    out_tokens = []
    resp = requests.post(url=inp_url, json=inp_json)
    if resp.status_code == 200:
        data_v = resp.json()
        for j in data_v["web_widgets"]["post_list"]:
            try:
                out_tokens.append(j['data']['token'])
            except:
                continue
    else:
        return 0
    return out_tokens, data_v['last_post_date'], data_v['first_post_date']

# %%
def first_get_tokens(inp_url):
    f_post_date = 0
    #l_post_date = 0
    js_v = {"page": 0,
            "json_schema": {"category": {"value": "plot-old"}, "query": "زمین",
                            "sort": {"value": "sort_date"}},
            "last-post-date": int(str(time.time()).replace('.', ''))}

    try:
        l_p_date = requests.post(url=inp_url, json=js_v).json()['last_post_date']
    except:
        l_p_date = int(str(time.time()).replace('.', ''))
    out_tokens = []
    k = 0
    while True:
        json_v = {"page": k,
                  "json_schema": {"category": {"value": "plot-old"}, "query": "زمین",
                                  "sort": {"value": "sort_date"}},
                  "last-post-date": l_p_date}

        result = get_tokens(inp_url, json_v)
        if result == 0:
            break
        else:
            if k == 0:
                f_post_date = result[2]
            out_tokens += result[0]
            l_p_date = result[1]
            k += 1
    return out_tokens, l_p_date, f_post_date

# %%
def second_get_toknes(inp_url, end_date):
    f_post_date = 0
    out_tokens = []
    json_v = {"page": 0,
              "json_schema": {"category": {"value": "plot-old"}, "query": "زمین",
                              "sort": {"value": "sort_date"}},
              "last-post-date": int(str(time.time()).replace('.', ''))}
    try:
        l_p_date = requests.post(url=inp_url, json=json_v).json()['last_post_date']
    except:
        l_p_date = int(str(time.time()).replace('.', ''))
    k = 0
    while True:
        if l_p_date > end_date:
            js_v = {"page": k,
                    "json_schema": {"category": {"value": "plot-old"}, "query": "زمین",
                                    "sort": {"value": "sort_date"}},
                    "last-post-date": l_p_date}
            result = get_tokens(inp_url, js_v)
            if result != 0:
                if k == 0:
                    f_post_date = result[2]
                out_tokens += result[0]
                l_p_date = result[1]
            else:
                break
        else:
            break
    return out_tokens, l_p_date, f_post_date

# %%
def get_true_data(inp_url):
    print('-', end='')
    page_ = requests.get(inp_url)
    if page_.status_code == 200:
        soup_v = BeautifulSoup(page_.text, 'html5lib')
        if soup_v.find_all('div', class_="kt-base-row__end kt-unexpandable-row__value-box") != []:
            return page_
        else:
            time.sleep(1)
            get_true_data(inp_url)
    else:
        if internet_connection():
            time.sleep(1)
            get_true_data(inp_url)

# %%
def get_data(inp_url):
    out_data = []
    page_ = requests.get(inp_url)
    if page_.status_code == 200:
        soup_v = BeautifulSoup(page_.text, 'html5lib')
        try:
            address = soup_v.find('div', class_='kt-page-title__title kt-page-title__title--responsive-sized')
            if address is not None:
                address = address.text
                #out_data.append(address.text)
            list_data = soup_v.find_all('div', class_="kt-base-row__end kt-unexpandable-row__value-box")
            attr = []
            for i in list_data:
                if len(list_data) > 0:
                    attr.append(adad_farsi_to_english(i.text))
                    #out_data.append(adad_farsi_to_english(i.text))
            description = soup_v.find_all('p', class_="kt-description-row__text kt-description-row__text--primary")[0]
            if description is not None:
                description = description.text
                #out_data.append(description.text)
            out_data = [address] + attr + [description]
        except:
            pass

    return out_data

# %%
def first_get_data_by_tokens(inp_tokens):
    df_out = pd.DataFrame({'address': [], 'area': [], 'price': [], 'unit_price': [], 'description': []})
    base_url = 'https://divar.ir/v/_/'
    for i in tqdm(inp_tokens):
        dest_url = base_url + i
        data_v = get_data(dest_url)
        if data_v != False:
            df_out.append(pd.Series(data_v, index=df_out.columns[:len(data_v)]), ignore_index=True)
            #df_out.loc[len(df_out.index) + 1] = data_v
    return df_out

# %%
def get_base_url(inp="https://api.divar.ir/v8/web-search/30/plot-old"):
    inp2 = input('Enter your url :')
    if inp2 == '':
        return inp
    else:
        return inp2


def get_base_url2(inp=None):
    if inp:
        return inp
    else:
        return "https://api.divar.ir/v8/web-search/30/plot-old"


def get_last_post_data(inp=None):
    if inp:
        return inp
    else:
        return int(str(time.time()).replace('.', ''))

# %%
if 'log.txt' in os.listdir():
    with open('log.txt', 'r') as f:
        if f.read() == '':
            f.close()
            with open('log.txt', 'w+') as f:
                f.write(f'{0},{time.time()}')
else:
    with open('log.txt', 'w') as f:
        f.write(f'{0},{time.time()}')

# %%
api_url = get_base_url2()
res = first_get_tokens(api_url)

# %%
res[0]
# Out:
# ['QZ5yPWfK',
#  'QZ5u_pKk',
#  'QZ5evHG3',
#  'QZ5qPK7O',
#  'QZ5ifxbT',
#  'QZ5iPsT8',
#  'QZ5iPBA2',
#  'QZ5evlhV',
#  'QZ5ePP8U',
#  'QZ5efAO-',
#  'QZwiK6GS',
#  'QZaikK-q',
#  'QZjWnr4l',
#  'QZ02KJxU',
#  'QZuqoHo4',
#  'QZ5Sfh04',
#  'QZGuo3HS',
#  'AZ2rONhM',
#  'QZ5Gfhgm',
#  'QZ0K8pcf',
#  'QZ5-euok',
#  'QZ56OJ6C',
#  'AZc98Fh8',
#  'QZ52Ob8O',
#  'QZ5mO59p',
#  'QZ5meyIv',
#  'QZ5eebeD',
#  'QZ5We53q',
#  'QZ5KuhK0',
#  'QZvG4VNp',
#  'AZsOC3RR',
#  'QZ5KppFo',
#  'QZ5qXM9I',
#  'QZ3WIOOn',
#  'QZ5C2Zhk',
#  'QZ5Cmmut',
#  'QZ5CGIqR',
#  'QZtev5Ol',
#  'QZ56lJmG',
#  'QZ2eshRv',
#  'QZ5mliBW',
#  'QZ5i1PWS',
#  'QZ5KVdlc',
#  'QZqebsJJ',
#  'QZ5O0sXy',
#  'QZ5uDffa',
#  'QZ5mjWHF',
#  'QZm2k2X4',
#  'QZ4W6V4J',
#  'QZ52ys7b',
#  'QZpCzDjy',
#  'QZ5uCH7e',
#  'QZqWWknd',
#  'QZ2uxMAn',
#  'QZ5-xmA2',
#  'QZ5-xrug',
#  'QZ5-hDlF',
#  'QZeW_MTt',
#  'QZ56RQcs',
#  'QZ5yBR35',
#  'QZ5uxklG',
#  'QZ3tThjJ',
#  'QZ5qxXI8',
#  'QZ5ixtlM',
#  'QZydWMW4',
#  'QZ5ah_5j',
# ...

# %%
res[1]
# Out:
# -1

# %%
res[2]
# Out:
# 1706674979054406

# %%
t = get_tokens(api_url, {"page": 0,
                         "json_schema": {"category": {"value": "plot-old"}, "query": "زمین",
                                         "sort": {"value": "sort_date"}},
                         "last-post-date": int(str(time.time()).replace('.', ''))})

# %%
t[1] < t[2]
# Out:
# True

# %%
a = get_true_data('https://divar.ir/v/+/' + res[0][10])
# Out:
# ----------------------------------

# %%
type(requests.get('https://divar.ir/v/+/' + res[0][10]).text)
# Out:
# str

# %%
def true_get_data(inp_url, try_num, timeout):
    c = 0
    while True:
        time.sleep(timeout)
        print('-', end='')
        resp = requests.get(inp_url)
        if resp.status_code == 200:
            page_ = resp.text
            if 'متر' in page_ and 'زمین' in page_ and 'متراژ' in page_ and 'قیمت کل' in page_ and 'قیمت هر متر' in page_:
                return resp
            else:
                if c < try_num:
                    c += 1
                    continue
                else:
                    return False
        else:
            if c < try_num:
                c += 1
                continue
            else:
                return False

# %%
#o=string.ascii_letters
#o[randint(0,len(o))]
# Out:
# 'w'

# %%
def true_get_data2(inp_url, try_num, timeout):
    o=string.ascii_letters
    c = 0
    make_url=inp_url
    while True:
        time.sleep(timeout)
        print('-', end='')
        resp = requests.get(make_url)
        make_url=make_url.replace('-',o[randint(0,len(o))])
        if resp.status_code == 200:
            page_ = resp.text
            if 'متر' in page_ and 'زمین' in page_ and 'متراژ' in page_ and 'قیمت کل' in page_ and 'قیمت هر متر' in page_:
                return resp
            else:
                if c < try_num:
                    c += 1
                    continue
                else:
                    return False
        else:
            if c < try_num:
                c += 1
                continue
            else:
                return False

# %%
a = true_get_data2(f'https://divar.ir/v/-/' + res[0][randint(0,len(res[0]))], 10, 10)
# Out:
# -

# %%
if a != False:
    print(a.text)
else:
    print(a)
# Out:
# <!doctype html>
# <html lang="fa-IR" dir="rtl">
# <head>
#   <title data-react-helmet="true">زمین جاده گاز|فروش زمین و کلنگی|کاشان|دیوار</title>
#   <meta data-react-helmet="true" name="viewport" content="width=992, initial-scale=1"/><meta data-react-helmet="true" name="description" content="زمین جاده گاز|فروش زمین و کلنگی|کاشان|خرید و فروش زمین 130 متری جاده گاز معاوضه با پژو پراید سمند
#
#
# زمین 130 متری جاده گاز (نزدیک چاه سوزنی)
# ...

# %%
d = first_get_data_by_tokens(res[0])
# Out:
#   0%|          | 0/1586 [00:00<?, ?it/s]C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5824\910399210.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_out.append(pd.Series(data_v, index=df_out.columns[:len(data_v)]), ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5824\910399210.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_out.append(pd.Series(data_v, index=df_out.columns[:len(data_v)]), ignore_index=True)
#   0%|          | 1/1586 [00:00<10:43,  2.46it/s]C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5824\910399210.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# ...

# %%
d
# Out:
# Empty DataFrame
# Columns: [address, area, price, unit_price, description]
# Index: []

# %%
for i in res[0]:
    a = get_data(f'https://divar.ir/v/_/' + i)
    #
    print(a)
    #time.sleep(10)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['زمین راوند ۳۰۰متری', 300, None, '۳۰۰متر دیوارکشی شده پشت کمیته امداد']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[219], line 2
#       1 for i in res[0]:
# ----> 2     a = get_data(f'https://divar.ir/v/_/'+i)
#       3 #
#       4     print(a)
#
# Cell In[190], line 3, in get_data(inp_url)
#       1 def get_data(inp_url):
# ...

# %%
get_data('https://divar.ir/v/_/' + res[0][0])
# Out:
# ['زمین فروشی شمالی در محور الهیه',
#  260,
#  11000000000,
#  42307000,
#  'زمین فوق قواده سوم به شبکه الهیه\n۱۲ متر\nمعر ۱۲ متری\nتوافق پیلوت با سه طبقه پیوست شده\nبسیا بسا موقعیت عالیبرای ساخت منزل ویلایی\nبافت کوچه همه نوساز \n\n\nچنانچه قصد خرید\nفروش زمین در محر امیرکبیر چهابانده صادق اصفهانی بلوار الهیه شهرک امیرالمومنین مجدالدین والته و.....با متراژ وقیپت های متغیر نیز وجود دارد خواشمندم لطفا تماس بگیرید\n***********\nمصیب ساجدبان']

# %%
get_data(f'https://divar.ir/v/_/{res[0][2]}')
# Out:
# []

# %%
requests.get(f'https://divar.ir/v/_/{res[0][2]}').text
# Out:
# '<!doctype html>\n<html lang="fa-IR" dir="rtl">\n<head>\n  \n  \n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n  <meta name="format-detection" content="telephone=no" />\n  <meta name="referrer" content="strict-origin-when-cross-origin" />\n  <link rel="preconnect" href="https://s100.divarcdn.com" />\n  <link rel="dns-prefetch" href="https://s100.divarcdn.com">\n    <link href=https://s100.divarcdn.com/statics/2024/01/IRANSansWeb.cdb118d6.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link href=https://s100.divarcdn.com/statics/2024/01/IRANSansWeb_Medium.9f338149.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2024/01/runtime.eb987de3.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/stat
# ...

# %%
requests.get(f'https://divar.ir/v/_/{res[0][3]}').text
# Out:
# '<!doctype html>\n<html lang="fa-IR" dir="rtl">\n<head>\n  \n  \n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n  <meta name="format-detection" content="telephone=no" />\n  <meta name="referrer" content="strict-origin-when-cross-origin" />\n  <link rel="preconnect" href="https://s100.divarcdn.com" />\n  <link rel="dns-prefetch" href="https://s100.divarcdn.com">\n    <link href=https://s100.divarcdn.com/statics/2024/01/IRANSansWeb.cdb118d6.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link href=https://s100.divarcdn.com/statics/2024/01/IRANSansWeb_Medium.9f338149.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2024/01/runtime.eb987de3.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/stat
# ...

# %%
t[0][0]
# Out:
# 'QZ4mrtlN'

# %%
get_data('https://divar.ir/v/_/' + t[0][0])
# Out:
# ['زمین شمالی/چهاربانده',
#  208,
#  7500000000,
#  36057000,
#  None,
#  'املاک چشم انداز\nمشاور شما: حیدری\n آدرس دفتر: خیابان امیر کبیر ،چهاربانده،جنب بستنی شکرریز \n__________________________________\nزمین فروشی\n۲۰۸متر شمالی\nسند و پروانه\nبر ۸/۵ متر\nدو طرف ساخته شده\nآماده ساخت\nمحله آرام\nخیابان امیرکبیر ،چهاربانده\n\n۷/۵۰۰\nلطفاً تماس بگیرید']

# %%
get_data('https://divar.ir/v/_/' + t[0][1])
# Out:
# ['زمین حسن آباد / لوکیشن خوب/',
#  148,
#  580000000,
#  3918000,
#  '148 متر زمین \nرو به رو مرکز درمانی \nامتیازات پای زمین \nمنطقه مسکونی \nپول لازمی \nقابلیت پرداخت شرایطی  \nزیر قیمت \nخرید و فروش املاک خود را ب مشاوران ما بسپارید']

# %%
get_data(f'https://divar.ir/v/_/{t[0][3]}')
# Out:
# []

# %%
get_data(f'https://divar.ir/v/_/{res[0][3]}')
# Out:
# []

# %%
len(t[0])
# Out:
# 24

# %%
t[0]
# Out:
# ['QZ4WcfMB',
#  'QZ3WIOOn',
#  'QZyqjM4t',
#  'QZ4O8ukb',
#  'QZ0K8pcf',
#  'QZ4KsFrv',
#  'QZ4-70P6',
#  'QZ4mrtlN',
#  'QZ4ir8z1',
#  'QZ4e6XHZ',
#  'QZ4OLZw4',
#  'QZ46K-vp',
#  'QZUKCDQX',
#  'QZ4q6xzQ',
#  'QZRa66gS',
#  'QZ4KaePk',
#  'QZ4eqAWn',
#  'QZ4KqkWW',
#  'QZ4GqlL9',
#  'QZm2k2X4',
#  'QZqWWknd',
#  'QZmOuK-T',
#  'QZ4GgSCK',
#  'QZ4CKJ_H']

# %%
res[0][:24]
# Out:
# ['QZ4CKJ_H',
#  'QZ4-ZqBN',
#  'QZwes0TO',
#  'QZ42Zako',
#  'QZ4qpJM2',
#  'QZ4SZqyi',
#  'QZ4qoJHB',
#  'QZk-ck-6',
#  'QZ4CoVM1',
#  'QZ0KBDRK',
#  'QZ4SRXKp',
#  'QZ2eshRv',
#  'QZ4KRsGp',
#  'QZ4mguFU',
#  'QZ4aASG5',
#  'QZ3yvPoC',
#  'QZ3Ofjcd',
#  'QZvet2ND',
#  'QZ3qung7',
#  'QZ3ie3vp',
#  'QZ3W-cJp',
#  'QZu6iydB',
#  'QZ3mtJbW',
#  'QZ3OthIk']

# %%
api_url = get_base_url2()
if 'log.txt' in os.listdir():
    with open('log.txt', 'r') as f:
        msg = f.read().split(',')
    if msg[0] == '0':
        tk = first_get_tokens(api_url)
        first_get_data_by_tokens(tk[0])
        with open('log.txt', 'w+'):
            f.write(f'{int(msg[0]) + 1},{tk[1]},{tk[2]}')
        df = first_get_data_by_tokens(tk[0])
        df.to_excel('out_data.xlsx')
    else:
        tk = second_get_toknes(api_url, int(str(msg[2]).replace('.', '')))
        first_get_data_by_tokens(tk[0])
        with open('log.txt', 'w+') as f:
            f.write(f'{int(msg[0]) + 1},{tk[1]},{tk[2]}')
        df = tk[0]
        df.to_excel('out_data.xlsx')
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 9
#       7 first_get_data_by_tokens(tk[0])
#       8 with open('log.txt', 'w+'):
# ----> 9     f.write(f'{int(msg[0]) + 1},{tk[1]},{tk[2]}')
#      10 df = first_get_data_by_tokens(tk[0])
#      11 df.to_excel('out_data.xlsx')
#
# ValueError: I/O operation on closed file.

# %%
0 == []
# Out:
# False

# %%
for i in range(50):
    with open('test.txt','a') as f:
        f.write(f'{i}-{time.time()}\n')

# %%
with open('test.txt','r') as f:
    print(f.readlines()[-1])
# Out:
# 49-1706704658.283583

# %%
a=time.time()
a
# Out:
# 1707074399.7508357

# %%
type(a)
# Out:
# float

# %%
time.localtime(a)
# Out:
# time.struct_time(tm_year=2024, tm_mon=2, tm_mday=4, tm_hour=22, tm_min=49, tm_sec=59, tm_wday=6, tm_yday=35, tm_isdst=0)

# %%
time.localtime(time.time())[2]
# Out:
# 4

# %%
type(time.localtime(time.time())[2])
# Out:
# int

# %%
time.localtime(time.time())[:3]
# Out:
# (2024, 2, 5)

# %%
type(time.localtime(time.time())[:3])
# Out:
# tuple

# %%
with open('test2.txt','w+') as f:
    f.write(f"{time.localtime(time.time())[:3]}")

# %%
with open('test2.txt','r') as f:
    print(f.read())
# Out:
# (2024, 2, 5)

# %%
with open("F:\my project\data\divar_kashan_real_state\dist\\run.txt",'w+') as f:
    f.write(f"{time.localtime(time.time())[:3]}")

# %%
with open("F:\my project\data\divar_kashan_real_state\dist\\run.txt",'r') as f:
    a=f.read()

# %%
a
# Out:
# '(2024, 2, 5)'

# %%
f"{time.localtime(time.time())[:3]}"
# Out:
# '(2024, 2, 4)'

# %%
a == f"{time.localtime(time.time())[:3]}"
# Out:
# True

# %%
for x in range (0,5):
    b = "Loading" + "." * x
    print (b, end="\r")
    time.sleep(1)
# Out:
# Loading....

# %%
a=requests.get('https://api.divar.ir/v8/posts-v2/web/QZPLMH94')

# %%
a=a.json()

# %%
p=a['seo']['unavailable_after'].split('T')[0].split('-')

# %%
p
# Out:
# ['2024', '03', '18']

# %%
p[1]=str(int(p[1])-1)

# %%
p
# Out:
# ['2024', '2', '18']

# %%
'-'.join(p)
# Out:
# '2024-2-18'
