# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cur = pd.read_excel('F:\my project\dataset\currecies.xlsx')

# %%
cur
# Out:
#         year/currency      1960      1961      1962      1963      1964  \
# 0       chf inflation  1.438795  1.845398  4.315993  3.440213  3.080557
# 1   inflation adj chf  0.985612  0.967424  0.925670  0.893825  0.866290
# 2       usd inflation  1.457976  1.070724  1.198773  1.239669  1.278912
# 3   inflation adj usd  0.985420  0.974869  0.963183  0.951242  0.939077
# 4       aud inflation  3.728814  2.287582 -0.319489  0.641026  2.866242
# 5   inflation adj aud  0.962712  0.940689  0.943694  0.937645  0.910770
# 6        ir inflation  9.822411  3.162564  0.721321  0.371850  3.814490
# 7    inflation adj ir  0.901776  0.873257  0.866958  0.863734  0.830787
# 8                 NaN       NaN       NaN       NaN       NaN       NaN
# 9              usd/ir  1.092755  1.116360  1.110992  1.101314  1.130346
# 10            usd/chf  0.999805  1.007696  1.040525  1.064238  1.084021
# 11            aud/usd  0.976956  0.964939  0.979767  0.985706  0.969857
#
# ...

# %%
data = cur.values.transpose()
data
# Out:
# array([['chf inflation', 'inflation adj chf', 'usd inflation',
#         'inflation adj usd', 'aud inflation', 'inflation adj aud',
#         'ir inflation', 'inflation adj ir', nan, 'usd/ir', 'usd/chf',
#         'aud/usd'],
#        [1.43879470321088, 0.9856120529678912, 1.45797598627786,
#         0.9854202401372214, 3.72881355932205, 0.9627118644067795,
#         9.82241081297881, 0.901775891870212, nan, 1.0927551390773351,
#         0.9998053870890761, 0.9769556430794645],
#        [1.84539787448659, 0.9674235890917381, 1.07072414764723,
#         0.9748691076702689, 2.2875816993464, 0.9406890439791734,
#         3.16256439585737, 0.8732566485834994, nan, 1.1163603612427047,
#         1.007696234268508, 0.9649388175067126],
#        [4.31599287754383, 0.9256696558908597, 1.19877334820185,
#         0.9631826366276645, -0.319488817891384, 0.9436944402858163,
#         0.721320571656317, 0.86695766873391, nan, 1.1109915412989884,
#         1.0405252354315346, 0.9797668732795256],
# ...

# %%
data[0]
# Out:
# array(['chf inflation', 'inflation adj chf', 'usd inflation',
#        'inflation adj usd', 'aud inflation', 'inflation adj aud',
#        'ir inflation', 'inflation adj ir', nan, 'usd/ir', 'usd/chf',
#        'aud/usd'], dtype=object)

# %%
curr_df = pd.DataFrame(data, index=cur.columns, columns=data[0])
curr_df.drop('year/currency', axis=0, inplace=True)

# %%
curr_df
# Out:
#      chf inflation inflation adj chf usd inflation inflation adj usd  \
# 1960      1.438795          0.985612      1.457976           0.98542
# 1961      1.845398          0.967424      1.070724          0.974869
# 1962      4.315993           0.92567      1.198773          0.963183
# 1963      3.440213          0.893825      1.239669          0.951242
# 1964      3.080557           0.86629      1.278912          0.939077
# ...            ...               ...           ...               ...
# 2018      0.936335          0.222896      2.442583          0.102059
# 2019      0.362886          0.222087       1.81221          0.100209
# 2020     -0.725875          0.223699      1.233584          0.098973
# 2021      0.581814          0.222398      4.697859          0.094324
# 2022           3.4          0.214836           8.6          0.086212
#
#      aud inflation inflation adj aud ir inflation inflation adj ir  NaN  \
# ...

# %%
curr_df.drop(np.NaN, axis=1, inplace=True)

# %%
curr_df
# Out:
#      chf inflation inflation adj chf usd inflation inflation adj usd  \
# 1960      1.438795          0.985612      1.457976           0.98542
# 1961      1.845398          0.967424      1.070724          0.974869
# 1962      4.315993           0.92567      1.198773          0.963183
# 1963      3.440213          0.893825      1.239669          0.951242
# 1964      3.080557           0.86629      1.278912          0.939077
# ...            ...               ...           ...               ...
# 2018      0.936335          0.222896      2.442583          0.102059
# 2019      0.362886          0.222087       1.81221          0.100209
# 2020     -0.725875          0.223699      1.233584          0.098973
# 2021      0.581814          0.222398      4.697859          0.094324
# 2022           3.4          0.214836           8.6          0.086212
#
#      aud inflation inflation adj aud ir inflation inflation adj ir  \
# 1960      3.728814          0.962712     9.822411         0.901776
# ...

# %%
curr_df.to_csv('F:\my project\dataset\currnecies.csv')

# %%
curr_df['irr_us_inf_adj'] = 0
curr_df
# Out:
#      chf inflation inflation adj chf usd inflation inflation adj usd  \
# 1960      1.438795          0.985612      1.457976           0.98542
# 1961      1.845398          0.967424      1.070724          0.974869
# 1962      4.315993           0.92567      1.198773          0.963183
# 1963      3.440213          0.893825      1.239669          0.951242
# 1964      3.080557           0.86629      1.278912          0.939077
# ...            ...               ...           ...               ...
# 2018      0.936335          0.222896      2.442583          0.102059
# 2019      0.362886          0.222087       1.81221          0.100209
# 2020     -0.725875          0.223699      1.233584          0.098973
# 2021      0.581814          0.222398      4.697859          0.094324
# 2022           3.4          0.214836           8.6          0.086212
#
#      aud inflation inflation adj aud ir inflation inflation adj ir  \
# 1960      3.728814          0.962712     9.822411         0.901776
# ...

# %%
curr_df['irr_us_inf_adj'][1960] = 1 + ((curr_df['ir inflation'][1960] - curr_df['usd inflation'][1960]) / 100)
curr_df['irr_us_inf_adj'][1960]
# Out:
# 1.0836443482670095

# %%
for i in curr_df.index[1:]:
    curr_df['irr_us_inf_adj'][i] = curr_df['irr_us_inf_adj'][i - 1] * (
            1 + ((curr_df['ir inflation'][i] - curr_df['usd inflation'][i]) / 100))
curr_df
# Out:
#      chf inflation inflation adj chf usd inflation inflation adj usd  \
# 1960      1.438795          0.985612      1.457976           0.98542
# 1961      1.845398          0.967424      1.070724          0.974869
# 1962      4.315993           0.92567      1.198773          0.963183
# 1963      3.440213          0.893825      1.239669          0.951242
# 1964      3.080557           0.86629      1.278912          0.939077
# ...            ...               ...           ...               ...
# 2018      0.936335          0.222896      2.442583          0.102059
# 2019      0.362886          0.222087       1.81221          0.100209
# 2020     -0.725875          0.223699      1.233584          0.098973
# 2021      0.581814          0.222398      4.697859          0.094324
# 2022           3.4          0.214836           8.6          0.086212
#
#      aud inflation inflation adj aud ir inflation inflation adj ir  \
# 1960      3.728814          0.962712     9.822411         0.901776
# ...

# %%
curr_df['irr_us_inf_adj'][2022] / curr_df['irr_us_inf_adj'][1978]
# Out:
# 958.608998316318

# %%
# Out:
# Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022],
#       dtype='object')

# %%
#for i in curr_df.index[18:]:
#    print(i, end=' ')
# Out:
# 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022

# %%
#curr_df['ir inflation'][1978] - curr_df['usd inflation'][1978]
# Out:
# 4.09100536526518

# %%
k = 1
for i in curr_df.index[:]:
    #print(i,end=' ')
    k *= 1 + ((curr_df['ir inflation'][i] - curr_df['usd inflation'][i]) / 100)

k
# Out:
# 1416.0482009982804

# %%
curr_df
# Out:
#      chf inflation inflation adj chf usd inflation inflation adj usd  \
# 1960      1.438795          0.985612      1.457976           0.98542
# 1961      1.845398          0.967424      1.070724          0.974869
# 1962      4.315993           0.92567      1.198773          0.963183
# 1963      3.440213          0.893825      1.239669          0.951242
# 1964      3.080557           0.86629      1.278912          0.939077
# ...            ...               ...           ...               ...
# 2018      0.936335          0.222896      2.442583          0.102059
# 2019      0.362886          0.222087       1.81221          0.100209
# 2020     -0.725875          0.223699      1.233584          0.098973
# 2021      0.581814          0.222398      4.697859          0.094324
# 2022           3.4          0.214836           8.6          0.086212
#
#      aud inflation inflation adj aud ir inflation inflation adj ir  \
# 1960      3.728814          0.962712     9.822411         0.901776
# ...

# %%
ir_wl=pd.read_excel('F:\my project\dataset\curr\ir_world.xlsx')
ir_wl
# Out:
#          Country Name Country Code                         Indicator Name  \
# 0  Iran, Islamic Rep.          IRN  Inflation, consumer prices (annual %)
# 1               World          WLD  Inflation, consumer prices (annual %)
#
#        1960      1961      1962     1963     1964      1965      1966  ...  \
# 0  9.822411  3.162564  0.721321  0.37185  3.81449  2.154375 -0.388149  ...
# 1       NaN       NaN       NaN      NaN      NaN       NaN       NaN  ...
#
#         2012       2013       2014       2015      2016      2017       2018  \
# 0  27.256813  36.603036  16.606553  12.484682  7.245425  8.044924  18.014118
# 1   3.725327   2.621050   2.346269   1.434318  1.550016  2.192010   2.438737
#
#         2019       2020       2021
# 0  39.907346  30.594139  43.389016
# 1   2.186902   1.920968   3.495058
#
# [2 rows x 65 columns]

# %%
ir_wl[2022]=[52,8.9]
ir_wl
# Out:
#          Country Name Country Code                         Indicator Name  \
# 0  Iran, Islamic Rep.          IRN  Inflation, consumer prices (annual %)
# 1               World          WLD  Inflation, consumer prices (annual %)
#
#        1960      1961      1962     1963     1964      1965      1966  ...  \
# 0  9.822411  3.162564  0.721321  0.37185  3.81449  2.154375 -0.388149  ...
# 1       NaN       NaN       NaN      NaN      NaN       NaN       NaN  ...
#
#         2013       2014       2015      2016      2017       2018       2019  \
# 0  36.603036  16.606553  12.484682  7.245425  8.044924  18.014118  39.907346
# 1   2.621050   2.346269   1.434318  1.550016  2.192010   2.438737   2.186902
#
#         2020       2021  2022
# 0  30.594139  43.389016  52.0
# 1   1.920968   3.495058   8.9
#
# [2 rows x 66 columns]

# %%
ir_wl.drop(['Country Name','Indicator Name'],axis=1,inplace=True)
ir_wl.index=ir_wl['Country Code']

# %%
ir_wl.drop('Country Code',axis=1,inplace=True)
ir_wl
# Out:
#                   1960      1961      1962     1963     1964      1965  \
# Country Code
# IRN           9.822411  3.162564  0.721321  0.37185  3.81449  2.154375
# WLD                NaN       NaN       NaN      NaN      NaN       NaN
#
#                   1966     1967      1968      1969  ...       2013  \
# Country Code                                         ...
# IRN          -0.388149  1.59761  0.690361  3.593195  ...  36.603036
# WLD                NaN      NaN       NaN       NaN  ...   2.621050
#
#                    2014       2015      2016      2017       2018       2019  \
# Country Code
# IRN           16.606553  12.484682  7.245425  8.044924  18.014118  39.907346
# WLD            2.346269   1.434318  1.550016  2.192010   2.438737   2.186902
#
#                    2020       2021  2022
# Country Code
# IRN           30.594139  43.389016  52.0
# WLD            1.920968   3.495058   8.9
#
# [2 rows x 63 columns]

# %%
ir_wl.index
# Out:
# Index(['IRN', 'WLD'], dtype='object', name='Country Code')

# %%
ir_wl_df=pd.DataFrame(ir_wl.values.transpose(),index=ir_wl.columns,columns=ir_wl.index)
ir_wl_df
# Out:
# Country Code        IRN       WLD
# 1960           9.822411       NaN
# 1961           3.162564       NaN
# 1962           0.721321       NaN
# 1963           0.371850       NaN
# 1964           3.814490       NaN
# ...                 ...       ...
# 2018          18.014118  2.438737
# 2019          39.907346  2.186902
# 2020          30.594139  1.920968
# 2021          43.389016  3.495058
# 2022          52.000000  8.900000
#
# [63 rows x 2 columns]

# %%
data_copy=1+ir_wl_df/100

# %%
data_copy
# Out:
# Country Code       IRN       WLD
# 1960          1.098224       NaN
# 1961          1.031626       NaN
# 1962          1.007213       NaN
# 1963          1.003718       NaN
# 1964          1.038145       NaN
# ...                ...       ...
# 2018          1.180141  1.024387
# 2019          1.399073  1.021869
# 2020          1.305941  1.019210
# 2021          1.433890  1.034951
# 2022          1.520000  1.089000
#
# [63 rows x 2 columns]

# %%
ir_acc=1
wld_acc=1
ir_wl_adj=1
for i in ir_wl_df.index[21:]:
    ir_acc*=data_copy['IRN'][i]
    wld_acc*=data_copy['WLD'][i]
    ir_wl_adj*=(data_copy['IRN'][i])/(data_copy['WLD'][i])

# %%
data_copy['ir_inf_adj']=1
#data_copy['wld_inf_adj']=1
for i in data_copy.index[1:]:
    data_copy['ir_inf_adj'][i]=data_copy['ir_inf_adj'][i-1]*data_copy['IRN'][i]
    #data_copy['wld_inf_adj'][i]=data_copy['wld_inf_adj'][i-1]*data_copy['WLD'][i]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13520\978571354.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_copy['ir_inf_adj'][i]=data_copy['ir_inf_adj'][i-1]*data_copy['IRN'][i]

# %%
data_copy['wld_inf_adj']=1
data_copy['wld_inf_adj'][1980]=1
for i in data_copy.index[21:]:
    data_copy['wld_inf_adj'][i]=data_copy['wld_inf_adj'][i-1]*data_copy['WLD'][i]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13520\2601065005.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_copy['wld_inf_adj'][1980]=1
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13520\2601065005.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_copy['wld_inf_adj'][i]=data_copy['wld_inf_adj'][i-1]*data_copy['WLD'][i]

# %%
data_copy
# Out:
# Country Code       IRN       WLD    ir_inf_adj  wld_inf_adj
# 1960          1.098224       NaN      1.000000     1.000000
# 1961          1.031626       NaN      1.031626     1.000000
# 1962          1.007213       NaN      1.039067     1.000000
# 1963          1.003718       NaN      1.042931     1.000000
# 1964          1.038145       NaN      1.082713     1.000000
# ...                ...       ...           ...          ...
# 2018          1.180141  1.024387   2784.203309     7.579712
# 2019          1.399073  1.021869   3895.304945     7.745473
# 2020          1.305941  1.019210   5087.039956     7.894261
# 2021          1.433890  1.034951   7294.256550     8.170170
# 2022          1.520000  1.089000  11087.269956     8.897315
#
# [63 rows x 4 columns]

# %%
data_copy['WLD/irr']=data_copy['ir_inf_adj']/data_copy['wld_inf_adj']
data_copy
# Out:
# Country Code       IRN       WLD    ir_inf_adj  wld_inf_adj      WLD/irr
# 1960          1.098224       NaN      1.000000     1.000000     1.000000
# 1961          1.031626       NaN      1.031626     1.000000     1.031626
# 1962          1.007213       NaN      1.039067     1.000000     1.039067
# 1963          1.003718       NaN      1.042931     1.000000     1.042931
# 1964          1.038145       NaN      1.082713     1.000000     1.082713
# ...                ...       ...           ...          ...          ...
# 2018          1.180141  1.024387   2784.203309     7.579712   367.323097
# 2019          1.399073  1.021869   3895.304945     7.745473   502.913765
# 2020          1.305941  1.019210   5087.039956     7.894261   644.397237
# 2021          1.433890  1.034951   7294.256550     8.170170   892.791290
# 2022          1.520000  1.089000  11087.269956     8.897315  1246.136602
#
# [63 rows x 5 columns]

# %%
plt.plot(data_copy['WLD/irr'][21:])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13520\2270264317.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(data_copy['WLD/irr'][21:])

# %%
wld_acc
# Out:
# 8.897315056956803

# %%
ir_acc/wld_acc*13
# Out:
# 4121.456056713187

# %%
data_copy['ir_inf_adj'][2022]/data_copy['ir_inf_adj'][1980]
# Out:
# 2820.761002306158

# %%
ir_wl_adj*13
# Out:
# 4121.456056713186
