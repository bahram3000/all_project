# %%
file=open("C:\\Users\\ADMIN\AppData\Roaming\MetaQuotes\\Terminal\\2506E8E7E4116548D478CE2C3598FAB1\MQL5\Files\\shakhS kl6-D1.prn",'r')

# %%
file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\ADMIN\\AppData\\Roaming\\MetaQuotes\\Terminal\\2506E8E7E4116548D478CE2C3598FAB1\\MQL5\\Files\\shakhS kl6-D1.prn' mode='r' encoding='cp1252'>

# %%
l=[]
for line in file:
    #print(line.split(','))
    l.append(line.split(','))
    #print(line)

# %%
l
# Out:
# [['<DTYYYYMMDD>', '<TIME>', '<OPEN>', '<HIGH>', '<LOW>', '<CLOSE>', '<VOL>\n'],
#  ['20081206',
#   '0',
#   '9249.0000',
#   '9249.0000',
#   '9168.0000',
#   '9178.0000',
#   '1095\n'],
#  ['20081207',
#   '0',
#   '9178.0000',
#   '9178.0000',
#   '9130.0000',
#   '9131.0000',
#   '1666\n'],
#  ['20081208',
#   '0',
#   '9103.0000',
#   '9103.0000',
#   '9080.0000',
#   '9089.0000',
#   '1873\n'],
#  ['20081210',
#   '0',
#   '9072.0000',
#   '9072.0000',
#   '9024.0000',
#   '9024.0000',
#   '1737\n'],
#  ['20081213',
#   '0',
#   '8973.0000',
#   '8973.0000',
#   '8973.0000',
#   '8973.0000',
#   '3108\n'],
#  ['20081214',
#   '0',
#   '8964.0000',
#   '8965.0000',
#   '8907.0000',
#   '8907.0000',
#   '2969\n'],
#  ['20081215',
#   '0',
#   '8902.0000',
#   '8904.0000',
#   '8891.0000',
#   '8891.0000',
#   '2007\n'],
#  ['20081216',
#   '0',
#   '8891.0000',
#   '8891.0000',
#   '8866.0000',
#   '8869.0000',
#   '2053\n'],
#  ['20081220',
#   '0',
#   '8862.0000',
# ...

# %%
len(l[0])-1
# Out:
# 6

# %%
for i in l:
    i[-1]=i[-1].replace("\n",'')

# %%
l[1:]
# Out:
# [['20081206', '0', '9249.0000', '9249.0000', '9168.0000', '9178.0000', '1095'],
#  ['20081207', '0', '9178.0000', '9178.0000', '9130.0000', '9131.0000', '1666'],
#  ['20081208', '0', '9103.0000', '9103.0000', '9080.0000', '9089.0000', '1873'],
#  ['20081210', '0', '9072.0000', '9072.0000', '9024.0000', '9024.0000', '1737'],
#  ['20081213', '0', '8973.0000', '8973.0000', '8973.0000', '8973.0000', '3108'],
#  ['20081214', '0', '8964.0000', '8965.0000', '8907.0000', '8907.0000', '2969'],
#  ['20081215', '0', '8902.0000', '8904.0000', '8891.0000', '8891.0000', '2007'],
#  ['20081216', '0', '8891.0000', '8891.0000', '8866.0000', '8869.0000', '2053'],
#  ['20081220', '0', '8862.0000', '8862.0000', '8854.0000', '8857.0000', '1645'],
#  ['20081221', '0', '8857.0000', '8861.0000', '8852.0000', '8852.0000', '1822'],
#  ['20081222', '0', '8840.0000', '8841.0000', '8832.0000', '8832.0000', '2600'],
#  ['20081223', '0', '8829.0000', '8830.0000', '8803.0000', '8803.0000', '2689'],
# ...

# %%
import numpy as np

# %%
arr1=np.array(l[1:])
arr1
# Out:
# array([['20081206', '0', '9249.0000', ..., '9168.0000', '9178.0000',
#         '1095'],
#        ['20081207', '0', '9178.0000', ..., '9130.0000', '9131.0000',
#         '1666'],
#        ['20081208', '0', '9103.0000', ..., '9080.0000', '9089.0000',
#         '1873'],
#        ...,
#        ['20231112', '0', '2054482.8800', ..., '2052563.6300',
#         '2053634.1300', '46'],
#        ['20231113', '0', '2053632.7500', ..., '2053632.7500',
#         '2055972.0000', '49'],
#        ['20231114', '0', '2055960.2500', ..., '2046407.0000',
#         '2046407.0000', '48']], dtype='<U12')
